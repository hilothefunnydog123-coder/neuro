# %% [markdown]
# # neuro — Stock/Option Forecaster (Colab Quickstart)
#
# Runs entirely in your browser on a free GPU. No Chromebook setup needed.
#
# **How to use:**
# 1. Open this notebook in Google Colab (File → Open → GitHub, paste the repo URL).
# 2. (Optional) Runtime → Change runtime type → **GPU**.
# 3. Runtime → **Run all**.
#
# ⚠️ Educational tool only — markets are noisy and unpredictable. Not financial advice.

# %% [markdown]
# ## 1. Get the code + install dependencies

# %%
# Clone the repo (edit the URL if your fork differs)
# !git clone https://github.com/hilothefunnydog123-coder/neuro.git || echo 'already cloned'
# %cd neuro
# !pip install -q -r requirements.txt

# %% [markdown]
# ## 2. Train
# Change the ticker / epochs / window however you like.

# %%
# !python -m src.cli train --ticker AAPL --epochs 50 --lookback 60 --horizon 5 --device auto

# %% [markdown]
# ## 3. Forecast the next few days

# %%
# !python -m src.cli predict --plot

# %% [markdown]
# ## 4. Show the forecast plot inline

# %%
from IPython.display import Image
Image('outputs/AAPL_forecast.png')
